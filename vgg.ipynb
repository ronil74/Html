# %% [markdown]
# <a href="https://colab.research.google.com/github/ronil74/Html/blob/gh-pages/vgg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unzipping the file
# !tar -xf /content/drive/My\ Drive/fer2013.tar.gz

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D ,BatchNormalization
from keras.layers import Dense, Activation, Dropout, Flatten

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers

import numpy as np
import matplotlib.pyplot as plt

#------------------------------
#cpu - gpu configuration
config = tf.compat.v1.ConfigProto( device_count = {'GPU': 0 , 'CPU': 56} ) #max: 1 gpu, 56 cpu
sess = tf.compat.v1.Session(config=config) 
tf.compat.v1.keras.backend.set_session(sess)
#------------------------------
#variables
num_classes = 7 #angry, disgust, fear, happy, sad, surprise, neutral
batch_size = 144
epochs = 75
#------------------------------
#read kaggle facial expression recognition challenge dataset (fer2013.csv)
#https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge

with open("fer2013/fer2013.csv") as f:
  content = f.readlines()

lines = np.array(content)

num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("instance length: ",len(lines[1].split(",")[1].split(" ")))

#------------------------------
#initialize trainset and test set
x_train, y_train, x_test, y_test = [], [], [], []

#------------------------------
#transfer train and test set data
for i in range(1,num_of_instances):
    try:
        emotion, img, usage = lines[i].split(",")
          
        val = img.split(" ")
            
        pixels = np.array(val, 'float32')
        
        emotion = keras.utils.to_categorical(emotion, num_classes)
    
        if 'Training' in usage:
            y_train.append(emotion)
            x_train.append(pixels)
        elif 'PublicTest' in usage:
            y_test.append(emotion)
            x_test.append(pixels)
    except:
      print("", end="")

#------------------------------
#data transformation for train and test sets
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

x_train /= 255 #normalize inputs between [0, 1]
x_test /= 255

x_train = x_train.reshape(x_train.shape[0], 48, 48, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], 48, 48, 1)
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
#------------------------------
img_width = x_train.shape[1]
img_height = x_train.shape[2]
img_depth = x_train.shape[3]
num_classes = 7
model = Sequential()
model.add(Conv2D(32, (3,3), padding="Same", activation='relu', input_shape=(48,48,1)))
model.add(BatchNormalization())
model.add(Conv2D(32, (5,5), padding="Same", activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(64, (3,3), padding="Same", activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (5,5), padding="Same", activation='relu'))
model.add(MaxPooling2D((2,2))) 
model.add(Dropout(0.5))
model.add(Conv2D(128, (3,3), padding="Same", activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (5,5), padding="Same", activation='relu'))
model.add(MaxPooling2D((2,2))) 
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(7, activation='softmax'))
# Out:
# number of instances:  35888
# instance length:  2304
# 28709 train samples
# 3589 test samples

# %%
batch_size = 64 #batch size of 32 performs the best.
epochs = 150
optims = [
    optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, name='Nadam'),
    optimizers.Adam(0.001),
]



train_datagen = ImageDataGenerator(
rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode = "nearest", 
    )



#------------------------------

model.compile(loss='categorical_crossentropy'
    , optimizer=keras.optimizers.Adam()
    , metrics=['accuracy']
)

#------------------------------

fit = True

if fit == True:
	#model.fit_generator(x_train, y_train, epochs=epochs) #train for all trainset
	history=model.fit(train_datagen.flow(x_train, y_train),validation_data=(x_test, y_test) ,batch_size=64, epochs=epochs) #train for randomly selected one
else:
	history=model.load_weights('/data/facial_expression_model_weights.h5') #load weights
	
#------------------------------
"""
#overall evaluation
score = model.evaluate(x_test, y_test)
print('Test loss:', score[0])
print('Test accuracy:', 100*score[1])
"""
#------------------------------
#function for drawing bar chart for emotion preditions
def emotion_analysis(emotions):
    objects = ('angry','disgust','fear', 'happy', 'sad', 'surprise', 'neutral')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()
# Out:
# Epoch 1/150
# 898/898 [==============================] - 16s 18ms/step - loss: 2.1313 - accuracy: 0.2390 - val_loss: 1.6982 - val_accuracy: 0.3051
# Epoch 2/150
# 898/898 [==============================] - 15s 17ms/step - loss: 1.6756 - accuracy: 0.3181 - val_loss: 1.5088 - val_accuracy: 0.4085
# Epoch 3/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.5261 - accuracy: 0.3890 - val_loss: 1.4264 - val_accuracy: 0.4193
# Epoch 4/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.4591 - accuracy: 0.4060 - val_loss: 1.4026 - val_accuracy: 0.4308
# Epoch 5/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.4152 - accuracy: 0.4305 - val_loss: 1.3333 - val_accuracy: 0.4723
# Epoch 6/150
# 898/898 [==============================] - 15s 17ms/step - loss: 1.3775 - accuracy: 0.4518 - val_loss: 1.2783 - val_accuracy: 0.5082
# Epoch 7/150
# 898/898 [==============================] - 15s 17ms/step - loss: 1.3410 - accuracy: 0.4717 - val_loss: 1.2684 - val_accuracy: 0.4907
# Epoch 8/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.3147 - accuracy: 0.4855 - val_loss: 1.2859 - val_accuracy: 0.5143
# Epoch 9/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.2979 - accuracy: 0.4975 - val_loss: 1.2814 - val_accuracy: 0.5099
# Epoch 10/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.2862 - accuracy: 0.5031 - val_loss: 1.2227 - val_accuracy: 0.5319
# Epoch 11/150
# 898/898 [==============================] - 15s 17ms/step - loss: 1.2845 - accuracy: 0.5049 - val_loss: 1.2223 - val_accuracy: 0.5249
# Epoch 12/150
# 898/898 [==============================] - 15s 17ms/step - loss: 1.2380 - accuracy: 0.5291 - val_loss: 1.2464 - val_accuracy: 0.5244
# Epoch 13/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.2408 - accuracy: 0.5291 - val_loss: 1.2038 - val_accuracy: 0.5578
# Epoch 14/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.2396 - accuracy: 0.5274 - val_loss: 1.2485 - val_accuracy: 0.5522
# Epoch 15/150
# 898/898 [==============================] - 15s 17ms/step - loss: 1.2089 - accuracy: 0.5420 - val_loss: 1.2051 - val_accuracy: 0.5525
# Epoch 16/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1907 - accuracy: 0.5542 - val_loss: 1.1428 - val_accuracy: 0.5709
# Epoch 17/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.1853 - accuracy: 0.5513 - val_loss: 1.2256 - val_accuracy: 0.5514
# Epoch 18/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1919 - accuracy: 0.5513 - val_loss: 1.1933 - val_accuracy: 0.5592
# Epoch 19/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.1810 - accuracy: 0.5621 - val_loss: 1.2527 - val_accuracy: 0.5561
# Epoch 20/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1715 - accuracy: 0.5596 - val_loss: 1.1859 - val_accuracy: 0.5720
# Epoch 21/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1585 - accuracy: 0.5588 - val_loss: 1.1642 - val_accuracy: 0.5754
# Epoch 22/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1534 - accuracy: 0.5616 - val_loss: 1.1062 - val_accuracy: 0.5893
# Epoch 23/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1567 - accuracy: 0.5631 - val_loss: 1.1775 - val_accuracy: 0.5823
# Epoch 24/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1334 - accuracy: 0.5756 - val_loss: 1.2354 - val_accuracy: 0.5765
# Epoch 25/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1227 - accuracy: 0.5780 - val_loss: 1.1146 - val_accuracy: 0.5910
# Epoch 26/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1329 - accuracy: 0.5764 - val_loss: 1.2312 - val_accuracy: 0.5653
# Epoch 27/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1325 - accuracy: 0.5754 - val_loss: 1.0752 - val_accuracy: 0.6060
# Epoch 28/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1115 - accuracy: 0.5793 - val_loss: 1.1104 - val_accuracy: 0.5910
# Epoch 29/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1067 - accuracy: 0.5824 - val_loss: 1.2020 - val_accuracy: 0.5926
# Epoch 30/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1074 - accuracy: 0.5835 - val_loss: 1.1524 - val_accuracy: 0.5965
# Epoch 31/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0935 - accuracy: 0.5866 - val_loss: 1.1012 - val_accuracy: 0.6071
# Epoch 32/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0943 - accuracy: 0.5878 - val_loss: 1.1369 - val_accuracy: 0.6021
# Epoch 33/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0877 - accuracy: 0.5915 - val_loss: 1.1292 - val_accuracy: 0.6043
# Epoch 34/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.1006 - accuracy: 0.5855 - val_loss: 1.1660 - val_accuracy: 0.5896
# Epoch 35/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0845 - accuracy: 0.5931 - val_loss: 1.1950 - val_accuracy: 0.5935
# Epoch 36/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0891 - accuracy: 0.5927 - val_loss: 1.1759 - val_accuracy: 0.5999
# Epoch 37/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0829 - accuracy: 0.5929 - val_loss: 1.1124 - val_accuracy: 0.6085
# Epoch 38/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0769 - accuracy: 0.5961 - val_loss: 1.1019 - val_accuracy: 0.6077
# Epoch 39/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0792 - accuracy: 0.5944 - val_loss: 1.1507 - val_accuracy: 0.6055
# Epoch 40/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.0647 - accuracy: 0.5979 - val_loss: 1.0644 - val_accuracy: 0.6158
# Epoch 41/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0700 - accuracy: 0.5978 - val_loss: 1.0824 - val_accuracy: 0.6169
# Epoch 42/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0618 - accuracy: 0.6055 - val_loss: 1.1725 - val_accuracy: 0.5737
# Epoch 43/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0621 - accuracy: 0.6038 - val_loss: 1.1417 - val_accuracy: 0.6049
# Epoch 44/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0561 - accuracy: 0.6058 - val_loss: 1.0606 - val_accuracy: 0.6124
# Epoch 45/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0541 - accuracy: 0.6041 - val_loss: 1.1370 - val_accuracy: 0.6049
# Epoch 46/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0423 - accuracy: 0.6127 - val_loss: 1.0532 - val_accuracy: 0.6272
# Epoch 47/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0498 - accuracy: 0.6061 - val_loss: 1.0540 - val_accuracy: 0.6174
# Epoch 48/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0496 - accuracy: 0.6040 - val_loss: 1.2327 - val_accuracy: 0.5893
# Epoch 49/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0451 - accuracy: 0.6041 - val_loss: 1.0747 - val_accuracy: 0.6049
# Epoch 50/150
# 898/898 [==============================] - 17s 18ms/step - loss: 1.0340 - accuracy: 0.6108 - val_loss: 1.1408 - val_accuracy: 0.5993
# Epoch 51/150
# 898/898 [==============================] - 17s 18ms/step - loss: 1.0435 - accuracy: 0.6095 - val_loss: 1.1297 - val_accuracy: 0.6077
# Epoch 52/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0445 - accuracy: 0.6090 - val_loss: 1.1123 - val_accuracy: 0.6102
# Epoch 53/150
# 898/898 [==============================] - 17s 18ms/step - loss: 1.0359 - accuracy: 0.6118 - val_loss: 1.1624 - val_accuracy: 0.5996
# Epoch 54/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0320 - accuracy: 0.6113 - val_loss: 1.0715 - val_accuracy: 0.6155
# Epoch 55/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0355 - accuracy: 0.6204 - val_loss: 1.1014 - val_accuracy: 0.6241
# Epoch 56/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0113 - accuracy: 0.6178 - val_loss: 1.0476 - val_accuracy: 0.6264
# Epoch 57/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0295 - accuracy: 0.6128 - val_loss: 1.0772 - val_accuracy: 0.6205
# Epoch 58/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0352 - accuracy: 0.6122 - val_loss: 1.0741 - val_accuracy: 0.6160
# Epoch 59/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0121 - accuracy: 0.6157 - val_loss: 1.1767 - val_accuracy: 0.6211
# Epoch 60/150
# 898/898 [==============================] - 16s 17ms/step - loss: 1.0197 - accuracy: 0.6172 - val_loss: 1.0953 - val_accuracy: 0.6222
# Epoch 61/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0056 - accuracy: 0.6258 - val_loss: 1.1091 - val_accuracy: 0.6219
# Epoch 62/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0100 - accuracy: 0.6221 - val_loss: 1.0796 - val_accuracy: 0.6244
# Epoch 63/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0185 - accuracy: 0.6199 - val_loss: 1.1036 - val_accuracy: 0.6191
# Epoch 64/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0072 - accuracy: 0.6253 - val_loss: 1.0927 - val_accuracy: 0.6280
# Epoch 65/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0082 - accuracy: 0.6259 - val_loss: 1.1569 - val_accuracy: 0.6169
# Epoch 66/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0190 - accuracy: 0.6186 - val_loss: 1.0331 - val_accuracy: 0.6255
# Epoch 67/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0099 - accuracy: 0.6259 - val_loss: 1.0094 - val_accuracy: 0.6350
# Epoch 68/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0052 - accuracy: 0.6217 - val_loss: 1.0498 - val_accuracy: 0.6258
# Epoch 69/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0017 - accuracy: 0.6245 - val_loss: 1.0932 - val_accuracy: 0.6180
# Epoch 70/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0107 - accuracy: 0.6209 - val_loss: 1.0440 - val_accuracy: 0.6233
# Epoch 71/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9968 - accuracy: 0.6297 - val_loss: 1.0550 - val_accuracy: 0.6199
# Epoch 72/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9962 - accuracy: 0.6303 - val_loss: 1.0517 - val_accuracy: 0.6269
# Epoch 73/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0010 - accuracy: 0.6240 - val_loss: 1.0833 - val_accuracy: 0.6258
# Epoch 74/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9970 - accuracy: 0.6260 - val_loss: 1.0146 - val_accuracy: 0.6330
# Epoch 75/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9778 - accuracy: 0.6323 - val_loss: 1.0728 - val_accuracy: 0.6258
# Epoch 76/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9937 - accuracy: 0.6269 - val_loss: 0.9914 - val_accuracy: 0.6358
# Epoch 77/150
# 898/898 [==============================] - 16s 18ms/step - loss: 1.0025 - accuracy: 0.6223 - val_loss: 1.0678 - val_accuracy: 0.6230
# Epoch 78/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9913 - accuracy: 0.6277 - val_loss: 1.0714 - val_accuracy: 0.6339
# Epoch 79/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9856 - accuracy: 0.6264 - val_loss: 1.1109 - val_accuracy: 0.6241
# Epoch 80/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9962 - accuracy: 0.6294 - val_loss: 1.0090 - val_accuracy: 0.6369
# Epoch 81/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9888 - accuracy: 0.6264 - val_loss: 1.0322 - val_accuracy: 0.6280
# Epoch 82/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9854 - accuracy: 0.6354 - val_loss: 1.0419 - val_accuracy: 0.6278
# Epoch 83/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9856 - accuracy: 0.6273 - val_loss: 1.1168 - val_accuracy: 0.6233
# Epoch 84/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9856 - accuracy: 0.6272 - val_loss: 0.9991 - val_accuracy: 0.6375
# Epoch 85/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9883 - accuracy: 0.6288 - val_loss: 1.0334 - val_accuracy: 0.6367
# Epoch 86/150
# 898/898 [==============================] - 17s 18ms/step - loss: 0.9757 - accuracy: 0.6373 - val_loss: 1.0101 - val_accuracy: 0.6356
# Epoch 87/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9725 - accuracy: 0.6359 - val_loss: 1.1015 - val_accuracy: 0.6219
# Epoch 88/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9829 - accuracy: 0.6321 - val_loss: 1.0901 - val_accuracy: 0.6286
# Epoch 89/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9895 - accuracy: 0.6276 - val_loss: 1.0885 - val_accuracy: 0.6205
# Epoch 90/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9826 - accuracy: 0.6324 - val_loss: 1.0365 - val_accuracy: 0.6325
# Epoch 91/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9660 - accuracy: 0.6375 - val_loss: 1.0018 - val_accuracy: 0.6431
# Epoch 92/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9838 - accuracy: 0.6322 - val_loss: 1.1114 - val_accuracy: 0.6280
# Epoch 93/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9618 - accuracy: 0.6422 - val_loss: 1.0535 - val_accuracy: 0.6294
# Epoch 94/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9969 - accuracy: 0.6254 - val_loss: 1.0730 - val_accuracy: 0.6325
# Epoch 95/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9691 - accuracy: 0.6364 - val_loss: 1.0236 - val_accuracy: 0.6420
# Epoch 96/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9619 - accuracy: 0.6396 - val_loss: 1.0445 - val_accuracy: 0.6213
# Epoch 97/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9719 - accuracy: 0.6363 - val_loss: 1.0786 - val_accuracy: 0.6213
# Epoch 98/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9630 - accuracy: 0.6398 - val_loss: 1.1199 - val_accuracy: 0.6199
# Epoch 99/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9529 - accuracy: 0.6465 - val_loss: 1.0417 - val_accuracy: 0.6392
# Epoch 100/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9700 - accuracy: 0.6419 - val_loss: 1.0321 - val_accuracy: 0.6470
# Epoch 101/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9649 - accuracy: 0.6379 - val_loss: 1.0462 - val_accuracy: 0.6347
# Epoch 102/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9653 - accuracy: 0.6412 - val_loss: 1.0653 - val_accuracy: 0.6308
# Epoch 103/150
# 898/898 [==============================] - 17s 18ms/step - loss: 0.9488 - accuracy: 0.6431 - val_loss: 1.0661 - val_accuracy: 0.6406
# Epoch 104/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9523 - accuracy: 0.6456 - val_loss: 1.0139 - val_accuracy: 0.6431
# Epoch 105/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9571 - accuracy: 0.6448 - val_loss: 1.0319 - val_accuracy: 0.6369
# Epoch 106/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9586 - accuracy: 0.6437 - val_loss: 1.0803 - val_accuracy: 0.6369
# Epoch 107/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9624 - accuracy: 0.6435 - val_loss: 1.0599 - val_accuracy: 0.6372
# Epoch 108/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9556 - accuracy: 0.6411 - val_loss: 1.0626 - val_accuracy: 0.6395
# Epoch 109/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9560 - accuracy: 0.6390 - val_loss: 1.0490 - val_accuracy: 0.6339
# Epoch 110/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9593 - accuracy: 0.6387 - val_loss: 1.0820 - val_accuracy: 0.6478
# Epoch 111/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9528 - accuracy: 0.6442 - val_loss: 1.0750 - val_accuracy: 0.6358
# Epoch 112/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9607 - accuracy: 0.6423 - val_loss: 1.0839 - val_accuracy: 0.6372
# Epoch 113/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9597 - accuracy: 0.6413 - val_loss: 1.0352 - val_accuracy: 0.6439
# Epoch 114/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9382 - accuracy: 0.6488 - val_loss: 1.0265 - val_accuracy: 0.6397
# Epoch 115/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9469 - accuracy: 0.6477 - val_loss: 1.0739 - val_accuracy: 0.6386
# Epoch 116/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9573 - accuracy: 0.6424 - val_loss: 1.0118 - val_accuracy: 0.6523
# Epoch 117/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9458 - accuracy: 0.6502 - val_loss: 1.0257 - val_accuracy: 0.6344
# Epoch 118/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9569 - accuracy: 0.6432 - val_loss: 1.0730 - val_accuracy: 0.6414
# Epoch 119/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9435 - accuracy: 0.6475 - val_loss: 1.1266 - val_accuracy: 0.6411
# Epoch 120/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9590 - accuracy: 0.6427 - val_loss: 1.0716 - val_accuracy: 0.6395
# Epoch 121/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9505 - accuracy: 0.6466 - val_loss: 1.1403 - val_accuracy: 0.6317
# Epoch 122/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9358 - accuracy: 0.6511 - val_loss: 1.0755 - val_accuracy: 0.6442
# Epoch 123/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9509 - accuracy: 0.6460 - val_loss: 1.0213 - val_accuracy: 0.6434
# Epoch 124/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9622 - accuracy: 0.6447 - val_loss: 0.9965 - val_accuracy: 0.6447
# Epoch 125/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9313 - accuracy: 0.6532 - val_loss: 1.1155 - val_accuracy: 0.6358
# Epoch 126/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9300 - accuracy: 0.6528 - val_loss: 1.0367 - val_accuracy: 0.6403
# Epoch 127/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9366 - accuracy: 0.6491 - val_loss: 1.0617 - val_accuracy: 0.6375
# Epoch 128/150
# 898/898 [==============================] - 17s 18ms/step - loss: 0.9476 - accuracy: 0.6457 - val_loss: 1.0465 - val_accuracy: 0.6447
# Epoch 129/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9285 - accuracy: 0.6522 - val_loss: 1.1229 - val_accuracy: 0.6314
# Epoch 130/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9376 - accuracy: 0.6519 - val_loss: 1.0265 - val_accuracy: 0.6473
# Epoch 131/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9400 - accuracy: 0.6524 - val_loss: 1.0973 - val_accuracy: 0.6264
# Epoch 132/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9284 - accuracy: 0.6526 - val_loss: 1.0709 - val_accuracy: 0.6336
# Epoch 133/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9361 - accuracy: 0.6523 - val_loss: 1.0575 - val_accuracy: 0.6464
# Epoch 134/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9400 - accuracy: 0.6502 - val_loss: 1.0493 - val_accuracy: 0.6439
# Epoch 135/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9360 - accuracy: 0.6478 - val_loss: 1.0267 - val_accuracy: 0.6308
# Epoch 136/150
# 898/898 [==============================] - 17s 18ms/step - loss: 0.9385 - accuracy: 0.6474 - val_loss: 1.0550 - val_accuracy: 0.6375
# Epoch 137/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9449 - accuracy: 0.6435 - val_loss: 1.0544 - val_accuracy: 0.6389
# Epoch 138/150
# 898/898 [==============================] - 17s 18ms/step - loss: 0.9398 - accuracy: 0.6469 - val_loss: 1.1305 - val_accuracy: 0.6461
# Epoch 139/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9288 - accuracy: 0.6552 - val_loss: 1.0716 - val_accuracy: 0.6428
# Epoch 140/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9358 - accuracy: 0.6552 - val_loss: 1.1244 - val_accuracy: 0.6261
# Epoch 141/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9343 - accuracy: 0.6499 - val_loss: 1.0383 - val_accuracy: 0.6411
# Epoch 142/150
# 898/898 [==============================] - 17s 18ms/step - loss: 0.9295 - accuracy: 0.6549 - val_loss: 1.0949 - val_accuracy: 0.6392
# Epoch 143/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9180 - accuracy: 0.6580 - val_loss: 1.0884 - val_accuracy: 0.6434
# Epoch 144/150
# 898/898 [==============================] - 17s 18ms/step - loss: 0.9392 - accuracy: 0.6538 - val_loss: 1.1005 - val_accuracy: 0.6389
# Epoch 145/150
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9258 - accuracy: 0.6521 - val_loss: 1.0404 - val_accuracy: 0.6464
# Epoch 146/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9318 - accuracy: 0.6499 - val_loss: 1.0139 - val_accuracy: 0.6534
# Epoch 147/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9241 - accuracy: 0.6569 - val_loss: 1.0110 - val_accuracy: 0.6461
# Epoch 148/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9215 - accuracy: 0.6584 - val_loss: 1.0007 - val_accuracy: 0.6434
# Epoch 149/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9297 - accuracy: 0.6467 - val_loss: 1.1530 - val_accuracy: 0.6180
# Epoch 150/150
# 898/898 [==============================] - 16s 18ms/step - loss: 0.9357 - accuracy: 0.6537 - val_loss: 1.0737 - val_accuracy: 0.6305

# %%
#Saving the model
model.save('model25.h5')

# %%
train_score = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy:', 100*train_score[1])
 
test_score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy:', 100*test_score[1])
# Out:
# Train loss: 0.8268616199493408
# Train accuracy: 69.89097595214844
# Test loss: 1.0737413167953491
# Test accuracy: 63.0537748336792

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2,1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(5))

# %%
from sklearn.metrics import classification_report, confusion_matrix
 
pred_list = []; actual_list = []
 
for i in predictions:
 
  pred_list.append(np.argmax(i))
 
for i in y_test:
 
  actual_list.append(np.argmax(i))
 
confusion_matrix(actual_list, pred_list)
# Out:
# array([[262,   2,  38,  23,  71,  20,  51],
#        [ 14,  31,   1,   4,   4,   1,   1],
#        [ 42,   1, 235,  14, 103,  41,  60],
#        [ 19,   1,  15, 734,  26,  28,  72],
#        [ 76,   0,  63,  24, 368,  16, 106],
#        [  9,   0,  22,  15,   9, 349,  11],
#        [ 35,   0,  35,  44,  97,   8, 388]])

# %%
from keras.models import load_model
model = load_model('model25.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-598a44a2fa9f> in <module>()
#       1 from keras.models import load_model
# ----> 2 model = load_model('model25.h5')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     209       filepath = path_to_string(filepath)
#     210       if isinstance(filepath, six.string_types):
# --> 211         loader_impl.parse_saved_model(filepath)
#     212         return saved_model_load.load(filepath, compile, options)
#     213
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     112                   (export_dir,
#     113                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 114                    constants.SAVED_MODEL_FILENAME_PB))
#     115
#     116
#
# OSError: SavedModel file does not exist at: model25.h5/{saved_model.pbtxt|saved_model.pb}

# %%
#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = 'photo.jpg'
true_image = image.load_img(file)
img = image.load_img(file, grayscale=True, target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48]);

plt.gray()
plt.imshow(true_image)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
import cv2
            
def facecrop(image):  
    facedata = "haarcascade_frontalface_default.xml"
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('capture.jpg', sub_face)
            #print ("Writing: " + image)

    except Exception as e:
        print (e)

    #cv2.imshow(image, img)


if __name__ == '__main__':
    facecrop('1.jpg')
# Out:
# 'NoneType' object has no attribute 'shape'

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
take_photo()
# Out:
# 'photo.jpg'
